# %% [markdown]
# <a href="https://colab.research.google.com/github/tenzin-g/Code-Translation-CodeNet/blob/main/Copy_of_Getting_Started_w_BERT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 5.3 MB 5.1 MB/s
# ...
#      |████████████████████████████████| 163 kB 52.6 MB/s
# ...
#      |████████████████████████████████| 7.6 MB 32.8 MB/s
# ...

# %% [markdown]
# #2. Try out BERT
#
# Feel free to swap out the sentence below for one of your own. But leave [MASK] in somewhere to allow BERT to predict the missing word.

# %%
from transformers import pipeline
unmasker = pipeline('fill-mask', model='bert-base-uncased')
unmasker("Artificial Intelligence [MASK] take over the world.")
# Out:
# Downloading:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Downloading:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# [{'score': 0.31824034452438354,
#   'token': 2064,
# ...

# %% [markdown]
# #3. Be Aware of Model Bias
#
#
# Let's see what jobs BERT suggests for a "man":

# %%
unmasker("The man worked as a [MASK].")
# Out:
# [{'score': 0.09747567027807236,
#   'token': 10533,
#   'token_str': 'carpenter',
#   'sequence': 'the man worked as a carpenter.'},
#  {'score': 0.05238332226872444,
#   'token': 15610,
#   'token_str': 'waiter',
#   'sequence': 'the man worked as a waiter.'},
#  {'score': 0.049626946449279785,
#   'token': 13362,
#   'token_str': 'barber',
#   'sequence': 'the man worked as a barber.'},
#  {'score': 0.0378861278295517,
#   'token': 15893,
#   'token_str': 'mechanic',
#   'sequence': 'the man worked as a mechanic.'},
#  {'score': 0.03768080845475197,
#   'token': 18968,
#   'token_str': 'salesman',
#   'sequence': 'the man worked as a salesman.'}]

# %% [markdown]
# ##Carpenter, Waiter, Barber, Mechanic, and Salesman
#
# Now let's see what jobs BERT suggests for "woman":

# %%
unmasker("The woman worked as a [MASK].")
# Out:
# [{'score': 0.21981488168239594,
#   'token': 6821,
#   'token_str': 'nurse',
#   'sequence': 'the woman worked as a nurse.'},
#  {'score': 0.15974114835262299,
#   'token': 13877,
#   'token_str': 'waitress',
#   'sequence': 'the woman worked as a waitress.'},
#  {'score': 0.1154731884598732,
#   'token': 10850,
#   'token_str': 'maid',
#   'sequence': 'the woman worked as a maid.'},
#  {'score': 0.03796885535120964,
#   'token': 19215,
#   'token_str': 'prostitute',
#   'sequence': 'the woman worked as a prostitute.'},
#  {'score': 0.030423814430832863,
#   'token': 5660,
#   'token_str': 'cook',
#   'sequence': 'the woman worked as a cook.'}]

# %% [markdown]
# ##Nurse, Waitress, Maid, Prostitute, and Cook..
#
# These gender biases are so important to be aware of and will affect all fine-tuned versions of this model.

# %% [markdown]
# #4. Some other BERT Notebooks you might enjoy:
#
# *   [A Visual Notebook to BERT for the First Time](https://colab.research.google.com/github/jalammar/jalammar.github.io/blob/master/notebooks/bert/A_Visual_Notebook_to_Using_BERT_for_the_First_Time.ipynb)
#
# *   [Train your tokenizer](https://colab.research.google.com/github/huggingface/notebooks/blob/master/examples/tokenizer_training.ipynb)
#
#
#
#
# +Don't forget to checkout the [Hugging Face Transformers Course](https://huggingface.co/course/chapter1/1) to learn more 🎉

# %% [markdown]
# #5. Testing

# %%
unmasker("[MASK] month !=0:")
# Out:
# [{'score': 0.25451749563217163,
#   'token': 1015,
#   'token_str': '1',
#   'sequence': '1 month! = 0 :'},
#  {'score': 0.11523032933473587,
#   'token': 1064,
#   'token_str': '|',
#   'sequence': '| month! = 0 :'},
#  {'score': 0.06347764283418655,
#   'token': 1027,
#   'token_str': '=',
#   'sequence': '= month! = 0 :'},
#  {'score': 0.06160192936658859,
#   'token': 2028,
#   'token_str': 'one',
#   'sequence': 'one month! = 0 :'},
#  {'score': 0.04920211061835289,
#   'token': 1037,
#   'token_str': 'a',
#   'sequence': 'a month! = 0 :'}]

# %%
unmasker("for i [MASK] range(month-1):")
# Out:
# [{'score': 0.5190132260322571,
#   'token': 1011,
#   'token_str': '-',
#   'sequence': 'for i - range ( month - 1 ) :'},
#  {'score': 0.05330430343747139,
#   'token': 21693,
#   'token_str': '##gm',
#   'sequence': 'for igm range ( month - 1 ) :'},
#  {'score': 0.02999691478908062,
#   'token': 2226,
#   'token_str': '##u',
#   'sequence': 'for iu range ( month - 1 ) :'},
#  {'score': 0.020539550110697746,
#   'token': 2290,
#   'token_str': '##g',
#   'sequence': 'for ig range ( month - 1 ) :'},
#  {'score': 0.01264708861708641,
#   'token': 5620,
#   'token_str': '##gs',
#   'sequence': 'for igs range ( month - 1 ) :'}]
